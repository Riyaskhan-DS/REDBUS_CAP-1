# %%
#importing libraries
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException, NoSuchElementException
import time
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd

# %%
#10 states links
state_links=["https://www.redbus.in/online-booking/ksrtc-kerala/?utm_source=rtchometile",
             "https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile",
             "https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile",
             "https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile",
             "https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile",
             "https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile",
             "https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile",
             "https://www.redbus.in/online-booking/astc/?utm_source=rtchometile",
             "https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile",
             "https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile"
]

# %% [markdown]
# # kerala routes / 1

# %%
#open the browser
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/ksrtc-kerala/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_KERALA = []
ROUTE_KERALA = []    


#retrive  bus links and route
def Kerala_link_route():  
   
     for i in range(1,3):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_KERALA.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_KERALA.append(route.text)    



        driver.execute_script('window.scrollBy(0,2000)')
        time.sleep(1)


        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(3)
            next_button.click()
        except:
            break

# %%
Kerala_link_route()

# %%
df_k = pd.DataFrame({
          "route_name" : ROUTE_KERALA,
          "route_link" : LINKS_KERALA
          
})

# %%
df_k
# Out:
#                          route_name  \
# 0            Bangalore to Kozhikode
# 1            Kozhikode to Bangalore
# 2            Kozhikode to Ernakulam
# 3            Ernakulam to Kozhikode
# 4               Bangalore to Kannur
# 5               Kozhikode to Mysore
# 6               Kannur to Bangalore
# 7   Kozhikode to Thiruvananthapuram
# 8               Mysore to Kozhikode
# 9    Bangalore to Kalpetta (kerala)
# 10   Kalpetta (kerala) to Bangalore
# 11  Thiruvananthapuram to Kozhikode
# 12            Kozhikode to Thrissur
# 13            Kozhikode to Kottayam
# 14            Kottayam to Kozhikode
#
#                                            route_link
# 0   https://www.redbus.in/bus-tickets/bangalore-to...
# 1   https://www.redbus.in/bus-tickets/kozhikode-to...
# 2   https://www.redbus.in/bus-tickets/kozhikode-to...
# 3   https://www.redbus.in/bus-tickets/ernakulam-to...
# 4   https://www.redbus.in/bus-tickets/bangalore-to...
# ...

# %%
# change dataframe to csv
df_k.to_csv('kearala_links.csv',index=False)

# %% [markdown]
# # Andhra routes / 2

# %%
#open the browser
driver= webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_ANDHRA = []
ROUTE_ANDHRA = []    


#retrive  bus links and route
def ANDHRA_link_route():
     driver.execute_script('window.scrollBy(0,2000)')
     time.sleep(1)
     for i in range(1,6):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_ANDHRA.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_ANDHRA.append(route.text)    
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(2)
            next_button.click()
        except:
            break

# %%
ANDHRA_link_route()

# %%
df_A = pd.DataFrame({
          "route_name" : ROUTE_ANDHRA,
          "route_link" : LINKS_ANDHRA
          
})

# %%
df_A
# Out:
#                                  route_name  \
# 0                   Hyderabad to Vijayawada
# 1                   Vijayawada to Hyderabad
# 2                       Hyderabad to Ongole
# 3                 Kakinada to Visakhapatnam
# 4                     Bangalore to Tirupati
# 5                       Bangalore to Kadapa
# 6                       Ongole to Hyderabad
# 7                       Kadapa to Bangalore
# 8    Chittoor (Andhra Pradesh) to Bangalore
# 9                 Visakhapatnam to Kakinada
# 10  Bangalore to Anantapur (andhra pradesh)
# 11   Bangalore to Chittoor (Andhra Pradesh)
# 12  Anantapur (andhra pradesh) to Bangalore
# 13                     Hyderabad to Kurnool
# 14                    Tirupati to Bangalore
# 15                Narasaraopet to Hyderabad
# 16                   Vinukonda to Hyderabad
# 17                   Hyderabad to Vinukonda
# 18              Visakhapatnam to Vijayawada
# 19                   Bangalore to Rayachoti
# ...

# %%
# change dataframe to csv
df_A.to_csv('Andhra_links.csv',index=False)

# %% [markdown]
# # GOA ROUTES / 3

# %%
#open the browser
driver= webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_GOA= []
ROUTE_GOA = []    


#retrive  bus links and route
def GOA_link_route():
     driver.execute_script('window.scrollBy(0,2000)')
     time.sleep(1)
     for i in range(1,5):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_GOA.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_GOA.append(route.text)    
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(2)
            next_button.click()
        except:
            break

# %%
GOA_link_route()

# %%
df_G = pd.DataFrame({
          "route_name" : ROUTE_GOA,
          "route_link" : LINKS_GOA
          
})

# %%
df_G
# Out:
#                          route_name  \
# 0                       Pune to Goa
# 1                       Goa to Pune
# 2                     Mumbai to Goa
# 3                  Bangalore to Goa
# 4                  Goa to Bangalore
# 5                     Goa to Mumbai
# 6                 Pandharpur to Goa
# 7                 Goa to Pandharpur
# 8                    Solapur to Goa
# 9    Calangute (goa) to Goa Airport
# 10     Goa to Kolhapur(Maharashtra)
# 11                   Goa to Solapur
# 12                    Goa to Sangli
# 13   Goa Airport to Calangute (goa)
# 14         Goa to Sangola (Solapur)
# 15         Sangola (Solapur) to Goa
# 16  Mopa Airport to Calangute (goa)
# 17  Calangute (goa) to Mopa Airport
# 18              Goa to Mopa Airport
# 19                     Goa to Miraj
# 20            Panaji to Goa Airport
# 21              Mopa Airport to Goa
# 22                Shivamogga to Goa
# 23           Margao to Mopa Airport
# 24               Goa Airport to Goa
# ...

# %%
# change dataframe to csv
df_G.to_csv('goa_links.csv',index=False)

# %% [markdown]
# # RAJASTAN ROUTES / 4

# %%
#open the browser
driver= webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_RAJASTAN = []
ROUTE_RAJASTAN = []    


#retrive  bus links and route
def RAJASTAN_link_route():
     driver.execute_script('window.scrollBy(0,2000)')
     time.sleep(1)
     for i in range(1,3):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_RAJASTAN.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_RAJASTAN.append(route.text)    
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(2)
            next_button.click()
        except:
            break

# %%
 RAJASTAN_link_route()

# %%
df_R = pd.DataFrame({
          "route_name" : ROUTE_RAJASTAN,
          "route_link" : LINKS_RAJASTAN
          
})

# %%
df_R
# Out:
#                                        route_name  \
# 0                              Udaipur to Jodhpur
# 1                                Jodhpur to Ajmer
# 2        Beawar (Rajasthan) to Jaipur (Rajasthan)
# 3                     Sikar to Jaipur (Rajasthan)
# 4                   Jaipur (Rajasthan) to Jodhpur
# 5   Aligarh (uttar pradesh) to Jaipur (Rajasthan)
# 6   Jaipur (Rajasthan) to Aligarh (uttar pradesh)
# 7                   Jodhpur to Beawar (Rajasthan)
# 8                    Jaipur (Rajasthan) to Pilani
# 9                Kishangarh to Jaipur (Rajasthan)
# 10                    Pali (Rajasthan) to Udaipur
# 11                    Udaipur to Pali (Rajasthan)
# 12                     Kota(Rajasthan) to Udaipur
# 13                 Jaipur (Rajasthan) to Bhilwara
# 14                               Sikar to Bikaner
# 15                Jaipur (Rajasthan) to Bharatpur
# 16                  Jaipur (Rajasthan) to Mathura
# 17          Jaipur (Rajasthan) to Kota(Rajasthan)
#
# ...

# %%
# change dataframe to csv
df_R.to_csv('rajastan_links.csv',index=False)

# %% [markdown]
# # Haryana routes / 5

# %%
#open the browser
driver= webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_HARYANA = []
ROUTE_HARYANA = []    


#retrive  bus links and route
def HARYANA_link_route():
     driver.execute_script('window.scrollBy(0,2000)')
     time.sleep(1)
     for i in range(1,5):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_HARYANA.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_HARYANA.append(route.text)    
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(2)
            next_button.click()
        except:
            break

# %%
HARYANA_link_route()

# %%
df_H = pd.DataFrame({
          "route_name" : ROUTE_HARYANA,
          "route_link" : LINKS_HARYANA
          
})

# %%
df_H
# Out:
#                                       route_name  \
# 0                                Delhi to Shimla
# 1      Chandigarh to Hamirpur (Himachal Pradesh)
# 2      Hamirpur (Himachal Pradesh) to Chandigarh
# 3                                Shimla to Delhi
# 4                            Delhi to Chandigarh
# 5           Hamirpur (Himachal Pradesh) to Delhi
# 6        Chamba (Himachal Pradesh) to Chandigarh
# 7           Delhi to Hamirpur (Himachal Pradesh)
# 8   Chandigarh to Dharamshala (Himachal Pradesh)
# 9             Delhi to Chamba (Himachal Pradesh)
# 10            Chamba (Himachal Pradesh) to Delhi
# 11                          Kangra to Chandigarh
# 12                          Shimla to Chandigarh
# 13             Delhi to Baddi (Himachal Pradesh)
# 14                                Delhi to Solan
# 15                             Delhi to Nalagarh
# 16  Dharamshala (Himachal Pradesh) to Chandigarh
# 17                        Palampur to Chandigarh
# ...

# %%
# change dataframe to csv
df_H.to_csv('haryana_links.csv',index=False)

# %% [markdown]
# # west bengal routes / 6

# %%
#open the browser
driver= webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_WESTBENGAL = []
ROUTE_WESTBENGAL = []    


#retrive  bus links and route
def WESTBENGAL_link_route():
     driver.execute_script('window.scrollBy(0,2000)')
     time.sleep(1)
     for i in range(1,5):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_WESTBENGAL.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_WESTBENGAL.append(route.text)    
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(2)
            next_button.click()
        except:
            break

# %%
WESTBENGAL_link_route()

# %%
df_WB = pd.DataFrame({
          "route_name" : ROUTE_WESTBENGAL,
          "route_link" : LINKS_WESTBENGAL
          
})

# %%
df_WB
# Out:
#                                            route_name  \
# 0                      Digha to Barasat (West Bengal)
# 1                                Durgapur to Calcutta
# 2                                   Digha to Calcutta
# 3                                    Kolkata to Digha
# 4                      Barasat (West Bengal) to Digha
# 5                                     Kolkata to Suri
# 6                  Barasat (West Bengal) to Midnapore
# 7                                Midnapore to Kolkata
# 8                   Barasat (West Bengal) to Kolaghat
# 9            Barasat (West Bengal) to Contai (Kanthi)
# 10                                     Habra to Digha
# 11  Barasat (West Bengal) to Nandakumar (west bengal)
# 12                  Kolkata to Durgapur (West Bengal)
# 13                                     Digha to Habra
# 14                 Midnapore to Barasat (West Bengal)
# 15                    Kolkata to Bolpur (West Bengal)
# ...

# %%
# change dataframe to csv
df_WB.to_csv('westbengal_links.csv',index=False)

# %% [markdown]
# # Uttra pradesh routes / 7

# %%
#open the browser
driver= webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_UTTRAPRADESH = []
ROUTE_UTTRAPRADESH = []    


#retrive  bus links and route
def UTTRAPRADESH_link_route():
     driver.execute_script('window.scrollBy(0,2000)')
     time.sleep(1)
     for i in range(1,6):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_UTTRAPRADESH.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_UTTRAPRADESH.append(route.text)    
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(2)
            next_button.click()
        except:
            break

# %%
UTTRAPRADESH_link_route()

# %%
df_UP = pd.DataFrame({
          "route_name" : ROUTE_UTTRAPRADESH,
          "route_link" : LINKS_UTTRAPRADESH
          
})

# %%
df_UP
# Out:
#                                            route_name  \
# 0                                   Delhi to Bareilly
# 1                                   Bareilly to Delhi
# 2                    Aligarh (uttar pradesh) to Delhi
# 3                    Delhi to Aligarh (uttar pradesh)
# 4                                Lucknow to Allahabad
# 5                                    Lucknow to Delhi
# 6                Delhi to Farrukhabad (Uttar Pradesh)
# 7                Farrukhabad (Uttar Pradesh) to Delhi
# 8                                     Badaun to Delhi
# 9                                Allahabad to Lucknow
# 10                                    Lucknow to Agra
# 11                   Sitapur (Uttar Pradesh) to Delhi
# 12                                    Delhi to Badaun
# 13                   Delhi to Sitapur (Uttar Pradesh)
# 14                                      Agra to Delhi
# 15                                 Delhi to Moradabad
# ...

# %%
# change dataframe to csv
df_UP.to_csv('uttrapradesh_links.csv',index=False)

# %% [markdown]
# # Assam routes / 8

# %%
#open the browser
driver= webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/astc/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_ASSAM = []
ROUTE_ASSAM = []    


#retrive  bus links and route
def ASSAM_link_route():
     driver.execute_script('window.scrollBy(0,2000)')
     time.sleep(1)
     for i in range(1,6):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_ASSAM.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_ASSAM.append(route.text)    
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(2)
            next_button.click()
        except:
            break

# %%
ASSAM_link_route()

# %%
df_AS = pd.DataFrame({
          "route_name" : ROUTE_ASSAM,
          "route_link" : LINKS_ASSAM
          
})

# %%
df_AS
# Out:
#                              route_name  \
# 0                    Tezpur to Guwahati
# 1                    Guwahati to Tezpur
# 2            Guwahati to Nagaon (Assam)
# 3            Nagaon (Assam) to Guwahati
# 4                  Goalpara to Guwahati
# 5             Jorhat to North Lakhimpur
# 6                    Dhubri to Guwahati
# 7                   Jorhat to Dibrugarh
# 8             North Lakhimpur to Jorhat
# 9           North Lakhimpur to Sibsagar
# 10                   Guwahati to Dhubri
# 11               Dhekiajuli to Guwahati
# 12          Sibsagar to North Lakhimpur
# 13                  Dibrugarh to Jorhat
# 14                    Jorhat to Dhemaji
# 15                   Jorhat to Tinsukia
# 16                  Tezpur to Dibrugarh
# 17                    Dhemaji to Jorhat
# 18            North Lakhimpur to Tezpur
# 19        Guwahati to Biswanath Charali
# 20         North Lakhimpur to Dibrugarh
# 21                   Tinsukia to Jorhat
# ...

# %%
# change dataframe to csv
df_AS.to_csv('assam_links.csv',index=False)

# %% [markdown]
# # south bengal routes / 9

# %%
#open the browser
driver= webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_SOUTHBENGAL = []
ROUTE_SOUTHBENGAL = []    


#retrive  bus links and route
def SOUTHBENGAL_link_route():
     driver.execute_script('window.scrollBy(0,2000)')
     time.sleep(1)
     for i in range(1,6):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_SOUTHBENGAL.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_SOUTHBENGAL.append(route.text)    
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(2)
            next_button.click()
        except:
            break

# %%
SOUTHBENGAL_link_route()

# %%
df_SB = pd.DataFrame({
          "route_name" : ROUTE_SOUTHBENGAL,
          "route_link" : LINKS_SOUTHBENGAL
          
})

# %%
df_SB
# Out:
#                                            route_name  \
# 0                                Durgapur to Calcutta
# 1                                  Kolkata to Burdwan
# 2                                  Haldia to Calcutta
# 3                                   Kolkata to Haldia
# 4                   Kolkata to Durgapur (West Bengal)
# 5                   Kolkata to Arambagh (West Bengal)
# 6                                Midnapore to Kolkata
# 7                                    Kolkata to Digha
# 8                                   Digha to Calcutta
# 9                                  Kolkata to Bankura
# 10                               Kolkata to Midnapore
# 11                   Kolkata to Asansol (West Bengal)
# 12                                Kolkata to Nimtouri
# 13                                Jhargram to Kolkata
# 14                         Kolkata to Contai (Kanthi)
# 15                                Kolkata to Kolaghat
# ...

# %%
# change dataframe to csv
df_SB.to_csv('southbengal_links.csv',index=False)

# %% [markdown]
# # Telungana routes / 10

# %%
#open the browser
driver= webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile")
driver.maximize_window()
wait = WebDriverWait(driver, 10)


LINKS_TELUNGANA = []
ROUTE_TELUNGANA = []    


#retrive  bus links and route
def TELUNGANA_link_route():
     driver.execute_script('window.scrollBy(0,2000)')
     time.sleep(1)
     for i in range(1,4):
         
        paths=driver.find_elements(By.XPATH,"//a[@class='route']")
        for links in paths:
            d = links.get_attribute("href")
            LINKS_TELUNGANA.append(d)
          # retrive the route links 
        for route in paths:
            ROUTE_TELUNGANA.append(route.text)    
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            time.sleep(2)
            next_button.click()
        except:
            break

# %%
 TELUNGANA_link_route()

# %%
df_T = pd.DataFrame({
          "route_name" : ROUTE_TELUNGANA,
          "route_link" : LINKS_TELUNGANA
          
})

# %%
df_T
# Out:
#                               route_name  \
# 0                Hyderabad to Vijayawada
# 1                   Khammam to Hyderabad
# 2                   Hyderabad to Khammam
# 3                 Hyderabad to Srisailam
# 4                Karimnagar to Hyderabad
# 5                Hyderabad to Karimnagar
# 6                Hyderabad to Mancherial
# 7                    Hyderabad to Nirmal
# 8                  Hyderabad to Adilabad
# 9                    Hyderabad to Ongole
# 10               Kothagudem to Hyderabad
# 11  Guntur (Andhra Pradesh) to Hyderabad
# 12  Hyderabad to Guntur (Andhra Pradesh)
# 13            Godavarikhani to Hyderabad
# 14               Hyderabad to Kothagudem
# 15               Hyderabad to Sathupally
# 16                 Hyderabad to Warangal
# 17                    Kodad to Hyderabad
# 18                 Jagityal to Hyderabad
# 19             Hyderabad to Bhadrachalam
# 20                 Hyderabad to Tirupati
# 21            Hyderabad to Godavarikhani
# ...

# %%
# change dataframe to csv
df_T.to_csv('telungana_links.csv',index=False)

# %% [markdown]
# # concat all the bus link and route names in one dataframe

# %%
df_total_links=pd.concat([df_k,df_A,df_T,df_G,df_R,df_H,df_SB,df_AS,df_UP,df_WB],ignore_index=True)

# %%
df_total_links
# Out:
#                             route_name  \
# 0               Bangalore to Kozhikode
# 1               Kozhikode to Bangalore
# 2               Kozhikode to Ernakulam
# 3               Ernakulam to Kozhikode
# 4                  Bangalore to Kannur
# ..                                 ...
# 328  Habra to Nandakumar (west bengal)
# 329                  Habra to Kolaghat
# 330          Kolkata to Mayapur ISKCON
# 331                     Habra to Heria
# 332       Midnapore to Kolkata Airport
#
#                                             route_link
# 0    https://www.redbus.in/bus-tickets/bangalore-to...
# 1    https://www.redbus.in/bus-tickets/kozhikode-to...
# 2    https://www.redbus.in/bus-tickets/kozhikode-to...
# 3    https://www.redbus.in/bus-tickets/ernakulam-to...
# 4    https://www.redbus.in/bus-tickets/bangalore-to...
# ..                                                 ...
# 328  https://www.redbus.in/bus-tickets/habra-to-nan...
# ...
